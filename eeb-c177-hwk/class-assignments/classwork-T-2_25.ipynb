# %% [markdown]
# ## Pseudo Code
#
# 1. What is the name of the author with the most entries in the databases? To find out, you'll need to parse the citations int he file. Note that you need to account for different formats. For example, you'll find:
#
#
# - (Morawitz, 1877)
# - Cockerell, 1901
# - (W. F. Kirby, 1990)
# - Meade-Waldo, 1914
# - Eardley & Brooks, 1989
# - Lepeletier & Audinet-Serville, 1828
# - Michener, LaBerge & Moure, 1955

# %% [markdown]
# #### Reading in the Bees
#
# Taking author counts and attributing praise to the best author.

# %%
import csv
import re
from collections import defaultdict

# %%
inputpath = "bee_list.txt"

# %%
authors = []
with open(inputpath, "r") as dset:
    data = csv.DictReader(dset, delimiter = "\t")
    for dic in data:
        authors.append(dic["Taxon Author"])
    header = data.fieldnames # use this bc of jupyter I/O file close

# %%
data.fieldnames # this shouldn't work outside of the open() -- but it did.........
# Out:
# ['Scientific Name', 'Taxon Author', 'tsn']

# %%
authors
# Out:
# ['Michener, 1986',
#  '(Cockerell, 1934)',
#  '(Timberlake, 1951)',
#  '(Timberlake, 1951)',
#  'Zavortink, 1994',
#  'Zavortink, 1974',
#  'Dours, 1873',
#  'Eversmann, 1852',
#  'Pérez, 1895',
#  '(Cockerell, 1922)',
#  'Warncke, 1967',
#  'Hirashima, 1962',
#  'Viereck, 1916',
#  'Warncke, 1967',
#  'Morawitz, 1886',
#  'Warncke, 1967',
#  'LaBerge, 1980',
#  'Morawitz, 1876',
#  'Morawitz, 1876',
#  'Friese, 1899',
#  'Friese, 1922',
#  'Morawitz, 1872',
#  'LaBerge, 1967',
#  'Dours, 1873',
#  'LaBerge, 1967',
#  'Warncke, 1974',
#  'Warncke, 1974',
#  'LaBerge, 1967',
#  'Warncke, 1967',
#  'Friese, 1909',
#  'Smith, 1879',
#  '(Scopoli, 1770)',
#  'Warncke, 1967',
#  'Thorp, 1969',
#  'Morawitz, 1876',
#  'Osytshnjuk, 1993',
#  'Osytshnjuk, 1993',
#  'Tadauchi, Hirashima & Matsumura, 1987',
#  'Tadauchi & Hirashima, 1984',
#  'Viereck, 1917',
#  'Popov, 1949',
#  'Hirashima, 1966',
#  'Viereck, 1917',
#  'Alfken, 1927',
#  'Radoszkowski, 1874',
#  '(Rossi, 1792)',
# ...

# %%
def check_auth(listofauthors):
    char = re.compile(r'..*') # finish this with a regex pattern

# %%
check_auth(authors)
# Out:
# 210

# %%
def check_auth2(listofauthors):
    char = re.compile(r'.*Hirashima[.*\.]') # finish this with a regex pattern
    count = 0
    for author in listofauthors:
        l = char.search(author)
        print(l)

# %%
check_auth2(authors)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
als = []
for line in authors:
    d = re.split(r'[;,\s]\'\s*', line) 
    als.append(d)
sort(als)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3494610f578d> in <module>
#       3     d = re.split(r'[;,\s]\'\s*', line)
#       4     als.append(d)
# ----> 5 unique(als)
#
# NameError: name 'unique' is not defined

# %%
auth_regex = re.compile(r'\(?([\w]+)')

# %% [markdown]
# # Thursday 2/27 class
# ## PSeudo code

# %%
with open(inputpath, 'r') as fr:
    data = csv.DictReader(fr, delimiter = '\t')
    header = data.fieldnames
    tax_auth = []
    for row in data:
        tax_auth.append(row['Taxon Author'])
        
auth_regex = re.compile(r'\(?([\w,\&\-\s]*),\s(\d{4})\)?')
# re.compile(author, whitepsace, 4 digits)
#? mark zero or more times
# one or more times
# dash zero ro more times 
#* match zero or more times all things in square brackets,
# between () are two groups of matching, match group 0 and group 1

# %%
mystring = 'Tadauchi, Miyanaga & Dawut, 2005'
mystring2 = '(Linnaeus, 1758)'
mystring4 = 'Meade-Waldo, 1914'
mystring3 = 'Michener, 1986'
test_strings = [mystring, mystring2, mystring3, mystring4]


re.findall(auth_regex, str(test_strings))
# Out:
# [('Tadauchi, Miyanaga & Dawut', '2005'),
#  ('Linnaeus', '1758'),
#  ('Michener', '1986'),
#  ('Meade-Waldo', '1914')]

# %%
for string in test_strings:
    print(re.match(auth_regex, string).group(1))
type(test_strings)
    #group 1 is foirst part of match from auth_regex
# Out:
# Tadauchi, Miyanaga & Dawut
# Linnaeus
# Michener
# Meade-Waldo
# list

# %%
authorss = list()
for string in tax_auth:
    appends = re.match(auth_regex, string).group(1)
    authorss.apppend(print(appends))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-f0033bac5522> in <module>
#       2 for string in tax_auth:
#       3     appends = re.match(auth_regex, string).group(1)
# ----> 4     authorss.apppend(print(appends))
#
# AttributeError: 'list' object has no attribute 'apppend'

# %%
print(authors)
# Out:
# ['Michener, 1986', '(Cockerell, 1934)', '(Timberlake, 1951)', '(Timberlake, 1951)', 'Zavortink, 1994', 'Zavortink, 1974', 'Dours, 1873', 'Eversmann, 1852', 'Pérez, 1895', '(Cockerell, 1922)', 'Warncke, 1967', 'Hirashima, 1962', 'Viereck, 1916', 'Warncke, 1967', 'Morawitz, 1886', 'Warncke, 1967', 'LaBerge, 1980', 'Morawitz, 1876', 'Morawitz, 1876', 'Friese, 1899', 'Friese, 1922', 'Morawitz, 1872', 'LaBerge, 1967', 'Dours, 1873', 'LaBerge, 1967', 'Warncke, 1974', 'Warncke, 1974', 'LaBerge, 1967', 'Warncke, 1967', 'Friese, 1909', 'Smith, 1879', '(Scopoli, 1770)', 'Warncke, 1967', 'Thorp, 1969', 'Morawitz, 1876', 'Osytshnjuk, 1993', 'Osytshnjuk, 1993', 'Tadauchi, Hirashima & Matsumura, 1987', 'Tadauchi & Hirashima, 1984', 'Viereck, 1917', 'Popov, 1949', 'Hirashima, 1966', 'Viereck, 1917', 'Alfken, 1927', 'Radoszkowski, 1874', '(Rossi, 1792)', '(Viereck, 1904)', 'LaBerge, 1986', 'Warncke, 1974', 'Perkins, 1914', 'Warncke, 1965', 'Smith, 1853', 'Robertson, 1891', 'Cockerell, 1897', 'Osytsh
# ...

# %%
mycounter = dict()
for entry in authors:
    authorlist = auth(entry)
    for author in authorlist:
        if author not in mycounter:
            mycounter[author] = 0
        mycounter[author] += 1
print(mycounter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-1c64e636acf2> in <module>
#       1 mycounter = dict()
#       2 for entry in authors:
# ----> 3     authorlist = auth_regex(entry)
#       4     for author in authorlist:
#       5         if author not in mycounter:
#
# TypeError: 're.Pattern' object is not callable

# %%
seeauth = re.compile(r'[A-D]o')

# %%
for o in authors:
    l = re.findall(seeauth, o)
    print(l)
# Out:
# []
# ['Co']
# []
# []
# []
# []
# ['Do']
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Do']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# ['Co']
# []
# []
# []
# []
# ['Co']
# []
# []
# ['Co']
# []
# []
# []
# []
# ['Co']
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# ['Do']
# []
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Bo']
# []
# ['Co']
# []
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# ['Do']
# []
# []
# ['Co']
# ['Co']
# ['Co']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Co']
# []
# []
# []
# []
# ['Co']
# []
# []
# ...

# %%
seeauth.search('coo thi is mo doo string')
